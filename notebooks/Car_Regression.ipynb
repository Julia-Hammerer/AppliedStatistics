# %% [markdown]
# # Regression Analysis on Car Seat Data
#
# After exploring the data and already finding some apparent relationships, we are going to build some regression models to predict the sale  prices.
#
# Author: Julia Hammerer, Vanessa Mai <br>
# Last Changes: 10.12.2018

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Regression-Analysis-on-Car-Seat-Data" data-toc-modified-id="Regression-Analysis-on-Car-Seat-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Regression Analysis on Car Seat Data</a></span><ul class="toc-item"><li><span><a href="#Function-Definitions" data-toc-modified-id="Function-Definitions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Function Definitions</a></span></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Preparation</a></span><ul class="toc-item"><li><span><a href="#Create-Training-and-Testingset" data-toc-modified-id="Create-Training-and-Testingset-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Create Training and Testingset</a></span></li><li><span><a href="#Normalize-Data-with-Standardscaler" data-toc-modified-id="Normalize-Data-with-Standardscaler-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Normalize Data with Standardscaler</a></span></li><li><span><a href="#Handle-outliers" data-toc-modified-id="Handle-outliers-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Handle outliers</a></span></li></ul></li><li><span><a href="#Baseline-Model" data-toc-modified-id="Baseline-Model-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Baseline Model</a></span></li><li><span><a href="#Ordinary-Least-Square-Regression-Model-(Iteration-1)" data-toc-modified-id="Ordinary-Least-Square-Regression-Model-(Iteration-1)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Ordinary Least Square Regression Model (Iteration 1)</a></span></li><li><span><a href="#Ordinary-Least-Square-Regression-Model-(Iteration-2)" data-toc-modified-id="Ordinary-Least-Square-Regression-Model-(Iteration-2)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Ordinary Least Square Regression Model (Iteration 2)</a></span><ul class="toc-item"><li><span><a href="#Residuals-vs.-Fitted" data-toc-modified-id="Residuals-vs.-Fitted-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Residuals vs. Fitted</a></span></li></ul></li><li><span><a href="#Ordinary-Least-Square-Regression-Model-(Iteration-3)" data-toc-modified-id="Ordinary-Least-Square-Regression-Model-(Iteration-3)-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Ordinary Least Square Regression Model (Iteration 3)</a></span><ul class="toc-item"><li><span><a href="#Residuals-vs.-Fitted" data-toc-modified-id="Residuals-vs.-Fitted-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Residuals vs. Fitted</a></span></li></ul></li><li><span><a href="#Ordinary-Least-Square---Cross-Validation" data-toc-modified-id="Ordinary-Least-Square---Cross-Validation-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Ordinary Least Square - Cross Validation</a></span></li><li><span><a href="#General-Least-Square-Regression" data-toc-modified-id="General-Least-Square-Regression-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>General Least Square Regression</a></span><ul class="toc-item"><li><span><a href="#Residuals-vs.-Fitted" data-toc-modified-id="Residuals-vs.-Fitted-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Residuals vs. Fitted</a></span></li></ul></li><li><span><a href="#Lasso-Regression-Iteration-1" data-toc-modified-id="Lasso-Regression-Iteration-1-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Lasso Regression Iteration 1</a></span></li><li><span><a href="#Lasso-Regression-Iteration-2" data-toc-modified-id="Lasso-Regression-Iteration-2-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Lasso Regression Iteration 2</a></span></li><li><span><a href="#Lasso-Regression-iteration-3" data-toc-modified-id="Lasso-Regression-iteration-3-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Lasso Regression iteration 3</a></span></li><li><span><a href="#Lasso-Regression-Iteration-4" data-toc-modified-id="Lasso-Regression-Iteration-4-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Lasso Regression Iteration 4</a></span></li><li><span><a href="#Elastic-Nets-Iteration-1" data-toc-modified-id="Elastic-Nets-Iteration-1-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Elastic Nets Iteration 1</a></span></li><li><span><a href="#Some-other-methods:-KNN-Regression" data-toc-modified-id="Some-other-methods:-KNN-Regression-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Some other methods: KNN-Regression</a></span></li><li><span><a href="#PCA-Analysis" data-toc-modified-id="PCA-Analysis-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>PCA Analysis</a></span></li><li><span><a href="#PCR-Analysis" data-toc-modified-id="PCR-Analysis-1.16"><span class="toc-item-num">1.16&nbsp;&nbsp;</span>PCR Analysis</a></span></li><li><span><a href="#PLS" data-toc-modified-id="PLS-1.17"><span class="toc-item-num">1.17&nbsp;&nbsp;</span>PLS</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-1.18"><span class="toc-item-num">1.18&nbsp;&nbsp;</span>XGBoost</a></span><ul class="toc-item"><li><span><a href="#Cross-validation-XGBoost" data-toc-modified-id="Cross-validation-XGBoost-1.18.1"><span class="toc-item-num">1.18.1&nbsp;&nbsp;</span>Cross-validation XGBoost</a></span></li><li><span><a href="#Hyperparameter" data-toc-modified-id="Hyperparameter-1.18.2"><span class="toc-item-num">1.18.2&nbsp;&nbsp;</span>Hyperparameter</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.19"><span class="toc-item-num">1.19&nbsp;&nbsp;</span>Summary</a></span></li></ul></li></ul></div>

# %%
import sys
sys.path.insert(0, '../helper/')

# %%
# load packages
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import pandas_profiling
import missingno as msno
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import warnings
import math
import statsmodels.formula.api as smf
import statsmodels.api as sm

from statsmodels.compat import lzip
from slugify import slugify
from pandas.tools.plotting import table
from plotly.offline import init_notebook_mode
from plotly.offline import iplot
from plotly.offline import plot
from scipy.stats import mannwhitneyu
from statsmodels.distributions.empirical_distribution import ECDF
from scipy import stats
from scipy.stats import pearsonr
from scipy.stats import norm
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split, KFold, cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LassoCV, ElasticNetCV, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_decomposition import PLSRegression, PLSSVD
from math import sqrt
from sklearn.decomposition.pca import PCA
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.grid_search import GridSearchCV
from helper import na_ratio_table
from helper import rmsle
from helper import reg_line
from helper import reg_model_results_plots
from helper import regression_model_metrics
from helper import results_summary_to_dataframe
from helper import lin_model
from helper import get_model_results
from helper import reg_model_results_plots
from helper import resid_plot
from helper import cross_fold
from helper import get_baseline_for_regression
from helper import outliers_idx

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Function Definitions
#
# Functions that have been created have been moved to the helper file, as they can be reused for different notebooks and in order to keep this notebook lean.

# %%
# all_models = pd.DataFrame(columns=['Model','train_res_df','test_res_df',
#                                    'mse_train','mse_test','rmsle_train',
#                                    'rmsle_test', 'r2_train', 'r2_test',
#                                    'se_train', 'se_test', 'train_obs',
#                                    'test_obs', 'outliers_obs'])

# def add_model_to_overview(model_summaries, modelname):
#     model_dic={}
# #     model_df=pd.DataFrame(columns=['Model','train_res_df','test_res_df',
# #                                    'mse_train','mse_test','rmsle_train',
# #                                    'rmsle_test', 'r2_train', 'r2_test',
# #                                    'se_train', 'se_test', 'train_obs',
# #                                    'test_obs', 'outliers_obs'])
#     model_dic.update({"Model":modelname})
#     model_dic.update({"train_res_df": model_summaries['train_res_df']})
#     model_dic.update({"test_res_df":model_summaries['test_res_df']})
#     model_dic.update({"mse_train":model_summaries['mse_train']})
#     model_dic.update({"mse_test":model_summaries['mse_test']})
#     model_dic.update({"r2_train":model_summaries['r2_train']})
#     model_dic.update({"r2_test":model_summaries['rmsle_train']})
#     model_dic.update({"rmsle_train":model_summaries['rmsle_test']})
#     model_dic.update({"rmsle_test":model_summaries['r2_test']})
#     model_dic.update({"se_train":model_summaries['se_train']})
#     model_dic.update({"se_test":model_summaries['se_test']})
#     model_dic.update({"train_obs":model_summaries['train_obs']})
#     model_dic.update({"test_obs":model_summaries['test_obs']})
#     model_dic.update({"outliers_obs":model_summaries['outliers_obs']})
#     model_df=pd.DataFrame(model_dic,index=[0])

# %% [markdown]
# ## Data Preparation
#
# In the EDA we saw that the data was quite clean, we only need to remove the ID "Unnamed: 0". There is no need for further data cleaning or specific preparation. We only need to prepare the training and testing set.

# %%
# load data
df = pd.read_csv("../data/Carseats.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Sales  CompPrice  Income  Advertising  Population  Price  \
# 0           1   9.50        138      73           11         276    120
# 1           2  11.22        111      48           16         260     83
# 2           3  10.06        113      35           10         269     80
# 3           4   7.40        117     100            4         466     97
# 4           5   4.15        141      64            3         340    128
#
#   ShelveLoc  Age  Education Urban   US
# 0       Bad   42         17   Yes  Yes
# 1      Good   65         10   Yes  Yes
# 2    Medium   59         12   Yes  Yes
# 3    Medium   55         14   Yes  Yes
# 4       Bad   38         13   Yes   No

# %%
df.drop(columns="Unnamed: 0", inplace=True)

# %%
CAT_FEATURES =df.select_dtypes(include="object").columns.tolist()

# %%
CAT_FEATURES
# Out:
# ['ShelveLoc', 'Urban', 'US']

# %%
df_hot1encoded= pd.get_dummies(df, columns=CAT_FEATURES, prefix=CAT_FEATURES, drop_first=True)

# %%
df_hot1encoded.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#    ShelveLoc_Good  ShelveLoc_Medium  Urban_Yes  US_Yes
# 0               0                 0          1       1
# 1               1                 0          1       1
# 2               0                 1          1       1
# 3               0                 1          1       1
# 4               0                 0          1       0

# %% [markdown]
# ### Create Training and Testingset

# %%
FEATURE_COLS=df_hot1encoded.drop(columns="Sales").columns

# %%
X= df_hot1encoded[FEATURE_COLS]
y= df_hot1encoded["Sales"]

# %%
# 70% Training, 30% Testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (280, 11)
# (120, 11)

# %% [markdown]
# ### Normalize Data with Standardscaler

# %%
# we also will use a StandardScaler in a second set

standardizer = StandardScaler().fit(X_train)

# FEATURE_COLS=df_hot1encoded.drop(columns="saleprice").columns

scaled_features=standardizer.transform(df_hot1encoded[FEATURE_COLS].values)

# %%
feature_df=feature_df=pd.DataFrame(scaled_features, index=df_hot1encoded[FEATURE_COLS].index, columns= df_hot1encoded[FEATURE_COLS].columns)

# %%
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(feature_df.copy(), y.copy(), test_size=0.3, random_state=0)

# %% [markdown]
# ### Handle outliers

# %%
df_all=X.copy()
df_all["Sales"]=y.copy()
outliers = outliers_idx(df_all, "Sales")
outliers_df = X.loc[X.index.isin(outliers)]

# %%
outliers_df
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 376        141      60           19         319     92   44         11
#
#      ShelveLoc_Good  ShelveLoc_Medium  Urban_Yes  US_Yes
# 376               1                 0          1       1

# %% [markdown]
# 1 outlier will be removed.

# %%
# #filter outliers 
X= X.loc[~X.index.isin(outliers)]
y= y.loc[~y.index.isin(outliers)]

# %%
X.shape
# Out:
# (399, 11)

# %%
df=X_train.copy()
df["Sales"]=y_train.copy()
outliers = outliers_idx(df, "Sales")
outliers_df = X_train.loc[X_train.index.isin(outliers)]

# %%
X_train.shape
# Out:
# (280, 11)

# %%
# #filter outliers for training
X_train= X_train.loc[~X_train.index.isin(outliers)]
y_train= y_train.loc[~y_train.index.isin(outliers)]

# %%
X_train.shape
# Out:
# (279, 11)

# %% [markdown]
# We have removed 16 outliers.
# Same process for the scaled data

# %%
df_scaled=X_train_scaled.copy()
df_scaled["Sales"]=y_train_scaled.copy()
outliers_scaled = outliers_idx(df_scaled, "Sales")
outliers_df_scaled = X_train_scaled.loc[X_train_scaled.index.isin(outliers)]

# %%
# #filter outliers for training
X_train_scaled= X_train_scaled.loc[~X_train.index.isin(outliers)]
y_train_scaled= y_train_scaled.loc[~y_train.index.isin(outliers)]

# %% [markdown]
# ## Baseline Model
# Let's start with building a baseline model, which is simply the means of all Sales.

# %%
# create Dummyregressor
Baseline = DummyRegressor(strategy='mean')

Baseline.fit(X_train, y_train)
Baseline.predict(X_test)
# Mean Accuracy ausgeben
print('Baseline MSE: %.2f' % mean_squared_error(Baseline.predict(X_test), y_test))
baseline_mse=mean_squared_error(Baseline.predict(X_test), y_test)
# Out:
# Baseline MSE: 6.90

# %% [markdown]
# Our baseline model, which uses the mean of all Sales of the Training set gives us a MSE of 6.90. Using different statistcal and machine learning methods we want to improve this score now.

# %% [markdown]
# ## Ordinary Least Square Regression Model (Iteration 1)
# - all variables

# %%
# let's start with a simple model and no further adjustments, we just put in all variables we have
ols_model = sm.OLS(y_train, X_train).fit()

# %%
y_pred=ols_model.predict(X_train)
mean_squared_error(y_pred, y_train)
# Out:
# 1.210444172718519

# %% [markdown]
# We can already see, that the MSE is much lower than our Baseline.

# %%
y_pred = ols_model.get_prediction(X_test)

# %%
y_pred=ols_model.predict(X_test)
mean_squared_error(y_pred, y_test)
# Out:
# 1.3941995576205024

# %% [markdown]
# Also, for the testing set, the results seem to be quite good in comparison with the Baseline.

# %%
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1227.
# Date:                Tue, 11 Dec 2018   Prob (F-statistic):          4.41e-222
# Time:                        14:11:36   Log-Likelihood:                -422.53
# No. Observations:                 279   AIC:                             867.1
# Df Residuals:                     268   BIC:                             907.0
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# CompPrice            0.1228      0.005     27.062      0.000       0.114       0.132
# Income               0.0198      0.002      8.213      0.000       0.015       0.025
# Advertising          0.1311      0.015      9.027      0.000       0.103       0.160
# Population           0.0009      0.000      1.941      0.053   -1.31e-05       0.002
# Price               -0.0994      0.004    -27.811      0.000      -0.106      -0.092
# Age                 -0.0321      0.004     -8.165      0.000      -0.040      -0.024
# Education            0.0409      0.023      1.765      0.079      -0.005       0.086
# ShelveLoc_Good       5.0567      0.204     24.740      0.000       4.654       5.459
# ShelveLoc_Medium     2.1990      0.161     13.697      0.000       1.883       2.515
# Urban_Yes            0.1101      0.150      0.733      0.464      -0.186       0.406
# US_Yes              -0.1056      0.198     -0.534      0.594      -0.495       0.283
# ==============================================================================
# Omnibus:                        1.009   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                0.809
# Skew:                           0.124   Prob(JB):                        0.667
# Kurtosis:                       3.090   Cond. No.                     1.21e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# MSE for both training AND testing set are much lower than the Baseline. The model performs quite well, with high R2, adj. R2 and F-Score
#
# First, we check the coefficents and p-values for each attributes. Let's have a look at those with p-values lower than the thumbrule 0.05.

# %%
ols_attr= results_summary_to_dataframe(ols_model)

# %%
ols_attr= ols_attr[ols_attr.pvals<=0.05]#.reset_index()

# %%
len(ols_attr)
# Out:
# 7

# %% [markdown]
# We would have 7 attributes for which we could reject the 0-Hypothesis, based on the OLS. Let's try building a model using these attributes.

# %% [markdown]
# ## Ordinary Least Square Regression Model (Iteration 2)
# - remove iteratively non-significant variables based on p-values of variables

# %%
ols_model_summaries={}
y_pred_name = "sales_predicted"

# %%
ols_model_2 = sm.OLS(y_train, X_train).fit()

while results_summary_to_dataframe(ols_model_2)["pvals"].apply(lambda x: x >= 0.05).any():
    ols_model_sign_attr=[]
    for i, e in enumerate(results_summary_to_dataframe(ols_model_2)["pvals"]):
        if e <=0.05:
            ols_model_sign_attr.append(results_summary_to_dataframe(ols_model_2).iloc[i]["attributes"])
    ols_model_2 = sm.OLS(y_train, X_train[ols_model_sign_attr]).fit()

# %%
# Test results
reg_test = ols_model_2.predict(X_test[ols_model_sign_attr])

# get results
reg_train_results_df = pd.DataFrame({"Sales": y_train.copy()})
reg_train_results_df[y_pred_name] = ols_model_2.fittedvalues
reg_train_results_df['set'] = 'TRAIN'

reg_test_results_df = pd.DataFrame({"Sales": y_test.copy()})
reg_test_results_df[y_pred_name] = reg_test
reg_test_results_df['set'] = 'TEST'

# metrics
baseline_val, baseline_mse, baseline_rmsle = get_baseline_for_regression(
    X_train=X_train,
    y_train=reg_train_results_df["Sales"],
    X_test=X_test,
    y_test=reg_test_results_df["Sales"])

mse_train, r2_train, adj_r2_train, st_error_train = regression_model_metrics(
    y=reg_train_results_df["Sales"],
    y_predicted=reg_train_results_df[y_pred_name],
    X=X_train)

mse_test, r2_test,adj_r2_test, st_error_test = regression_model_metrics(
    y=reg_test_results_df["Sales"],
    y_predicted=reg_test_results_df[y_pred_name],
    X=X_test)

rmsle_train=rmsle(ytest=reg_train_results_df["Sales"], 
                    ypred=reg_train_results_df[y_pred_name])
rmsle_test=rmsle(ytest=reg_test_results_df["Sales"], 
                     ypred=reg_test_results_df[y_pred_name])

ols_model_summaries = {'y_pred_name': y_pred_name,
                       'train_res_df': reg_train_results_df,
                       'test_res_df': reg_test_results_df,
                       'baseline_mse': baseline_mse,
                       'baseline_val': baseline_val,
                       'baseline_rmsle':baseline_rmsle,
                       'mse_train': mse_train,
                       'mse_test': mse_test,
                       'rmsle_train': rmsle_train,
                       'rmsle_test':rmsle_test,
                       'r2_train': r2_train,
                       'adj_r2_train': adj_r2_train,
                       'r2_test': r2_test,
                       'adj_r2_test': adj_r2_test,
                       'se_train': st_error_train,
                       'se_test': st_error_test,
                       'model_report': ols_model_2.summary(),
                       'train_obs': reg_train_results_df.shape[0],
                       'test_obs': reg_test_results_df.shape[0]}
# put all this in a function in case, i want to repeat this analysis

# %%
reg_model_results_plots(model_summaries=ols_model_summaries, y_pred_name="Sales_pred", y_name="Sales")

# %% [markdown]
# Results are surprisingly good, given that we barely optimize the model, the MSE is definitely smaller than are benchmark/baseline. if we look at the plot that compares Actual vs. Predicted, the data points are quite close to our regression line, which indicates a good prediction. If the data points were exactly on the regression line, we would have a perfect regression.

# %% [markdown]
# ### Residuals vs. Fitted

# %%
resid_plot(ols_model_2, y_train)

# %% [markdown]
# The residuals are close to but not exactly spread around a horizontal line.

# %%
sm.qqplot(ols_model_2.get_influence().resid_studentized_internal);

# %% [markdown]
# ## Ordinary Least Square Regression Model (Iteration 3)
# - use scaled data

# %%
ols_model_3 = sm.OLS(y_train_scaled, X_train_scaled).fit()

# %%
ols_model_3, ols_model_3_summary, sign_attr_3=lin_model(y_train_scaled, X_train_scaled, y_test_scaled, X_test_scaled,
                                                        reg_model="OLS",
                                                        y_pred_name="Sales_pred", 
                                                        y_name="Sales")

# %%
ols_model_3_summary
# Out:
# {'y_pred_name': 'Sales_pred', 'train_res_df':      Sales  Sales_pred    set
#  92    4.53   -2.626643  TRAIN
#  223   3.45   -3.034323  TRAIN
#  234   9.43    0.466201  TRAIN
#  232  13.14    5.020144  TRAIN
#  377   6.81   -0.792084  TRAIN
#  142   7.44    0.415298  TRAIN
#  22    5.08   -2.451938  TRAIN
#  252   8.31    0.080404  TRAIN
#  350   8.64    0.342512  TRAIN
#  168   7.30   -0.327276  TRAIN
#  150  10.49    2.624455  TRAIN
#  393   5.57   -2.654637  TRAIN
#  66    8.85    1.973231  TRAIN
#  240  10.31    2.345038  TRAIN
#  218   9.70    0.301040  TRAIN
#  101   6.20   -0.525517  TRAIN
#  311   6.15   -0.039453  TRAIN
#  194   7.23   -3.119446  TRAIN
#  326   4.69   -0.401201  TRAIN
#  17   12.29    3.534996  TRAIN
#  164   8.22   -0.702502  TRAIN
#  186   8.68    1.741397  TRAIN
#  30   13.55    5.338241  TRAIN
#  114   9.31    0.018816  TRAIN
#  263   7.77   -1.459593  TRAIN
#  103   5.07    1.083946  TRAIN
#  358   4.17   -1.035117  TRAIN
#  245  10.00    4.313443  TRAIN
#  235   5.53   -2.077851  TRAIN
#  116   5.08   -0.775288  TRAIN
#  ..     ...         ...    ...
#  197   2.52   -2.859617  TRAIN
#  243   7.82   -0.162628  TRAIN
#  115   8.54   -0.463929  TRAIN
#  265   5.31   -1.381208  TRAIN
#  72    5.52   -1.657834  TRAIN
#  333   5.87   -2.503467  TRAIN
#  25   14.90    7.439367  TRAIN
#  165   0.37   -5.620474  TRAIN
#  337   8.61    1.219459  TRAIN
#  384  12.85    2.919017  TRAIN
#  174   0.00   -5.857907  TRAIN
#  386   5.32   -2.124922  TRAIN
#  39    3.24   -2.248098  TRAIN
#  193  13.28    6.090873  TRAIN
#  314   7.72    2.300759  TRAIN
#  88    6.56   -0.972389  TRAIN
#  70    9.46    0.705914  TRAIN
#  87   11.70    2.385882  TRAIN
#  292  11.82    5.560017  TRAIN
#  242   4.68   -2.570654  TRAIN
#  277   7.80   -0.384405  TRAIN
#  211   9.39   -1.839278  TRAIN
#  9     4.69   -0.695763  TRAIN
#  359   3.13   -1.477529  TRAIN
#  195   4.19   -1.068710  TRAIN
#  251   3.72   -0.752892  TRAIN
#  323  10.36   -1.221020  TRAIN
#  192   7.56   -0.155890  TRAIN
#  117   8.80    1.110801  TRAIN
#  47    4.38    0.233854  TRAIN
#
#  [279 rows x 3 columns], 'test_res_df':      Sales  Sales_pred   set
#  132   9.54    0.811153  TEST
#  309  11.18    3.440442  TEST
#  341   7.38   -1.175089  TEST
#  196   4.10   -1.766493  TEST
#  246   6.90    1.356113  TEST
#  60    8.32   -1.618642  TEST
#  155   7.71    1.136616  TEST
#  261   5.71   -1.238956  TEST
#  141   6.53   -0.554651  TEST
#  214   4.83   -0.790945  TEST
#  37    4.95   -0.468388  TEST
#  134   3.67   -1.370011  TEST
#  113   6.01   -1.086646  TEST
#  348  12.57    4.317902  TEST
#  12    3.98   -2.870815  TEST
#  59    5.21   -1.159432  TEST
#  293  11.28    5.134401  TEST
#  140   6.03   -1.075449  TEST
#  206   4.97   -1.105723  TEST
#  199   6.42   -1.907605  TEST
#  176   5.61   -2.973875  TEST
#  268   6.53    0.217057  TEST
#  124   8.87    2.963809  TEST
#  344   8.43    3.099322  TEST
#  175   7.54   -2.235760  TEST
#  313   9.33    3.091031  TEST
#  78    4.43   -2.514665  TEST
#  15    8.71   -0.889545  TEST
#  286   7.53   -1.165031  TEST
#  102   5.30   -0.031574  TEST
#  ..     ...         ...   ...
#  380   9.64    0.025555  TEST
#  253   5.64   -1.318481  TEST
#  56   11.91    3.258998  TEST
#  8     6.54   -0.695763  TEST
#  190   8.79    1.315780  TEST
#  146   3.90   -3.204569  TEST
#  135   6.44   -3.979596  TEST
#  390   5.47   -1.889668  TEST
#  264   6.95   -1.098471  TEST
#  364  10.50    0.986998  TEST
#  250   9.16    0.107771  TEST
#  63    8.47    0.194661  TEST
#  312   6.80   -1.245695  TEST
#  159   9.32    3.180613  TEST
#  283   5.36    0.284244  TEST
#  340   7.50    3.298190  TEST
#  81    7.52    0.664441  TEST
#  349   9.32    2.205065  TEST
#  153   5.93   -1.365552  TEST
#  295   4.21   -3.374816  TEST
#  96    9.48    3.438675  TEST
#  89    7.95   -0.621838  TEST
#  296   8.21    2.267166  TEST
#  21   12.13    4.329100  TEST
#  365   6.53   -2.113724  TEST
#  216   5.73   -1.704905  TEST
#  259   5.12    0.698662  TEST
#  49   10.61    2.820417  TEST
#  238   7.36    0.692436  TEST
#  343   5.99   -1.935599  TEST
#
#  [120 rows x 3 columns], 'baseline_mse': 6.882, 'baseline_rmsle': 0.345, 'baseline_val': 7.372401433691756, 'mse_train': 57.61, 'mse_test': 58.003, 'rmsle_train': 2.1716826942058227, 'rmsle_test': 1.953315303656994, 'r2_train': -5.811103350346852, 'adj_r2_train': -6.091710604480991, 'r2_test': -7.628254607727538, 'adj_r2_test': -8.507058317773861, 'se_train': 1.78761064031722, 'se_test': 1.5734537506564432, 'model_report': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:                  Sales   R-squared:                       0.083
#  Model:                            OLS   Adj. R-squared:                  0.073
#  Method:                 Least Squares   F-statistic:                     8.305
#  Date:                Tue, 11 Dec 2018   Prob (F-statistic):           2.63e-05
#  Time:                        14:11:38   Log-Likelihood:                -961.37
#  No. Observations:                 279   AIC:                             1929.
#  Df Residuals:                     276   BIC:                             1940.
#  Df Model:                           3
#  Covariance Type:            nonrobust
#  ==================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------
#  CompPrice          1.5478      0.562      2.753      0.006       0.441       2.654
#  Price             -2.2591      0.560     -4.031      0.000      -3.362      -1.156
#  ShelveLoc_Good     1.3321      0.460      2.899      0.004       0.427       2.237
#  ==============================================================================
#  Omnibus:                        0.662   Durbin-Watson:                   0.112
#  Prob(Omnibus):                  0.718   Jarque-Bera (JB):                0.768
#  Skew:                           0.105   Prob(JB):                        0.681
#  Kurtosis:                       2.852   Cond. No.                         1.94
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """, 'train_obs': 279, 'test_obs': 120}

# %%
reg_model_results_plots(model_summaries=ols_model_3_summary, y_pred_name="Sales_pred", y_name="Sales")

# %% [markdown]
# Using the standardized data results in a much worse result. We also have negative values, which should not be possible.

# %% [markdown]
# ### Residuals vs. Fitted

# %%
# fitted values
model_fitted_y_2 = ols_model_3.fittedvalues;
# Basic plot
plot = sns.residplot(model_fitted_y_2, y_train, lowess=True, 
                     scatter_kws={'alpha': 0.5}, 
                     line_kws={'color': 'red', 
                               'lw': 1, 'alpha': 0.8});

plot.set_title('Residuals vs Fitted');
plot.set_xlabel('Fitted values');
plot.set_ylabel('Residuals');

# %% [markdown]
# ## Ordinary Least Square - Cross Validation
# - using the model from second iteration

# %%
predictors=" + ".join(ols_model_sign_attr)

# %%
predictors
# Out:
# 'CompPrice + Income + Advertising + Price + Age + ShelveLoc_Good + ShelveLoc_Medium'

# %%
# Model 1
results = cross_fold(df_hot1encoded, response='Sales', predictors=predictors)
display(results)
print(f'MSE Mean: {results["MSE"].mean():.2f}')
print(f'RMSLE Mean: {results["RMSLE"].mean():.2f}')
# Out:
#    Fold       MSE     RMSLE
# 0     0  1.032613  0.136018
# 1     1  0.899378  0.162603
# 2     2  0.931019  0.163089
# 3     3  0.806451  0.108411
# 4     4  1.238403  0.180296
# 5     5  1.246052  0.168475
# 6     6  1.777866  0.188584
# 7     7  1.015241  0.132577
# 8     8  0.882644  0.134853
# 9     9  0.765224  0.187743
# MSE Mean: 1.06
# RMSLE Mean: 0.16

# %% [markdown]
# ## General Least Square Regression

# %%
gls_model, gls_model_summary, gls_sign_attr=lin_model(y_train, X_train, y_test, X_test, 
                                                      reg_model="GLS",
                                                      y_pred_name="Sales_pred", 
                                                      y_name="Sales")

# %%
reg_model_results_plots(model_summaries=gls_model_summary,
                        y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# ### Residuals vs. Fitted

# %%
# Basic plot
plot = sns.residplot(gls_model.fittedvalues, y_train, lowess=True, 
                     scatter_kws={'alpha': 0.5}, 
                     line_kws={'color': 'red', 
                               'lw': 1, 'alpha': 0.8});

plot.set_title('Residuals vs Fitted');
plot.set_xlabel('Fitted values');
plot.set_ylabel('Residuals');

# %% [markdown]
# ## Lasso Regression Iteration 1
# Lasso helps us to reduce dimensions and drop unimportant attributes.

# %%
lasso1 = Lasso()
lasso1.set_params(alpha=0.5)
lasso1.fit(X_train, y_train)
print(lasso1.score(X_train, y_train))
print(lasso1.score(X_test, y_test))
# Out:
# 0.5962156728254253
# 0.42438017644213905

# %% [markdown]
# The R2 Scores are not very high. Let's have a further look

# %%
y_pred=lasso1.predict(X_test)

# %%
lasso_coef1=pd.Series(lasso1.coef_, index=X_train.columns)

# %%
(lasso_coef1[(lasso_coef1==0)].index.tolist())
# Out:
# ['Education', 'ShelveLoc_Medium', 'Urban_Yes', 'US_Yes']

# %% [markdown]
# We can see plenty 4 attributes which have coefficents of zero. Those are identified as irrelevant by the lasso regression and we are going to remove those from the analysis.

# %%
# make function to get number of irrelevant attributes
def get_irr_attr_lasso(lasso_model, X_train):
    lasso_coef=pd.Series(lasso_model.coef_, index=X_train.columns)
    irr_attr_lasso=lasso_coef[(lasso_coef==0)].index.tolist()
    return irr_attr_lasso

# %%
# make function to get number of irrelevant attributes
def get_attr_lasso(lasso_model, X_train):
    lasso_coef=pd.Series(lasso_model.coef_, index=X_train.columns)
    attr_lasso=lasso_coef[(lasso_coef!=0)].index.tolist()
    return attr_lasso

# %%
get_irr_attr_lasso(lasso1, X_train)
# Out:
# ['Education', 'ShelveLoc_Medium', 'Urban_Yes', 'US_Yes']

# %%
lasso_attr=lasso_coef1[lasso_coef1!=0]

# %%
lasso_attr.shape
# Out:
# (7,)

# %% [markdown]
# We have 7 attributes considered as important. It is the as in the OLS-Regression according to the p-values

# %%
lasso_attr=lasso_attr.index.tolist()

# %%
lasso = Lasso()
lasso.set_params(alpha=0.5)
lasso.fit(X_train[lasso_attr], y_train)
print(lasso.score(X_train[lasso_attr], y_train))
print(lasso.score(X_test[lasso_attr], y_test))
# Out:
# 0.5962156728254253
# 0.42438017644213905

# %%
y_pred=lasso.predict(X_test[lasso_attr])

# %%
mse_test, r2_test, adj_r2_test, st_error_test = regression_model_metrics(y_test, y_pred, 
                                                                         X_test)

# %%
lasso, lasso_summaries =  get_model_results(lasso,y_train, X_train[lasso_attr], 
                                            y_test, X_test[lasso_attr],
                                            y_pred_name="Sales_pred", 
                                            y_name="Sales")

# %%
reg_model_results_plots(lasso_summaries,
                        y_pred_name="Sales_pred",
                        y_name="Sales")

# %% [markdown]
# The lasso regression yields worse results than the simpler OLS and GLS

# %% [markdown]
# ## Lasso Regression Iteration 2
# - Using various alphas and comparing results

# %%
def lasso_r2(lambdas, X_train, y_train, X_test, y_test):
    '''
    Takes in a list of lambdas. 
    Outputs a dataframe containing the r2 of lasso regressions 
    from each lambda for training and testing data set.
    
    '''
    columns_list=["lambda", "R2_training", "R2_testing"]
    r_scores=pd.DataFrame(columns=columns_list)
    
    for l in lambdas:
        lasso=Lasso()
        lasso.set_params(alpha=l)
        lasso.fit(X_train, y_train)
        R2_train=lasso.score(X_train, y_train)
        R2_test=lasso.score(X_test, y_test)
        row=pd.DataFrame([[l,R2_train, R2_test]], columns=columns_list)
        r_scores=r_scores.append(row)
    return r_scores

def plot_lasso_lambdas(r_scores):
    plt.figure(figsize=(15,8)) 
    ax=plt.plot( 'lambda', 'R2_training', data=r_scores, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
    ax=plt.plot( 'lambda', 'R2_testing', data=r_scores, marker='o', markerfacecolor='red', markersize=12, color='tomato', linewidth=4)
#     plt.xscale("log")
    plt.legend()

# %%
l_min = 0.05 
l_max = 20
l_num = 20
lambdas = np.linspace(l_min,l_max, l_num)

# %%
plot_lasso_lambdas(lasso_r2(lambdas, X_train, y_train, X_test, y_test))

# %%
lasso_r2_results=lasso_r2(lambdas, X_train, y_train, X_test, y_test)

# %%
lasso_r2_results=lasso_r2_results.reset_index().drop(columns="index")

# %%
lasso_r2_results["R2_testing"].idxmax()
# Out:
# 0

# %%
lasso_r2_results.ix[lasso_r2_results["R2_testing"].idxmax()]
# Out:
# lambda         0.050000
# R2_training    0.878218
# R2_testing     0.804402
# Name: 0, dtype: float64

# %%
lasso2=Lasso()
lasso2.set_params(alpha=0.05)
lasso2.fit(X_train[lasso_attr], y_train)
# Out:
# Lasso(alpha=0.05, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso2, lasso_summaries2 =  get_model_results(lasso2,y_train,
                                              X_train[lasso_attr],
                                              y_test,
                                              X_test[lasso_attr],
                                              y_pred_name="Sales_pred", 
                                              y_name="Sales")

# %%
reg_model_results_plots(lasso_summaries2,
                        y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# Also, a decent mode.

# %%
len(get_attr_lasso(lasso2, X_train[lasso_attr]))
# Out:
# 7

# %%
get_attr_lasso(lasso2, X_train[lasso_attr])
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'Age',
#  'ShelveLoc_Good']

# %% [markdown]
# ## Lasso Regression iteration 3
#
# Crossvalidation

# %%
lasso_3 = LassoCV(cv=10, random_state=0, normalize=True).fit(X, y)
lasso_3.score(X,y)
# Out:
# 0.8703187671290147

# %%
lasso_3, lasso_summaries_3 =  get_model_results(lasso_3,y, X, y, X,
                                              y_pred_name="Sales_pred", 
                                              y_name="Sales")

# %%
reg_model_results_plots(lasso_summaries_3,
                        y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# Best Model so far. (based on MSE)

# %%
display(get_attr_lasso(lasso_3, X_train))
display(len(get_attr_lasso(lasso_3, X_train)))
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'Age',
#  'Education',
#  'ShelveLoc_Good',
#  'ShelveLoc_Medium',
#  'Urban_Yes',
#  'US_Yes']
# 11

# %%
get_irr_attr_lasso(lasso_3, X_train)
# Out:
# []

# %% [markdown]
# This model uses all attributes.

# %%
lasso_3_coef = pd.Series(lasso_3.coef_, index = X_train.columns).sort_values()
lasso_3_coef = lasso_3_coef[lasso_3_coef!=0]

# %%
lasso_3_coef.plot(kind="barh")

# %% [markdown]
# ## Lasso Regression Iteration 4
# - Cross validation
# - optimization of alphas

# %%
l_min = 0.05 
l_max = 20
l_num = 20
lambdas = np.linspace(l_min,l_max, l_num)

# %%
lasso4 = LassoCV(cv=10, random_state=0, alphas=lambdas, fit_intercept=True).fit(X, y)
lasso4.score(X,y)
# Out:
# 0.8618816611667021

# %%
lasso4, lasso_summaries_4 =  get_model_results(lasso4,y, X, y, X, 
                                               y_pred_name="Sales_pred", 
                                               y_name="Sales")

# %%
reg_model_results_plots(lasso_summaries_4,
                        y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
lasso4.alpha_
# Out:
# 0.05

# %% [markdown]
# Best alpha: `0.05`

# %% [markdown]
# Using an intercept and an optimization of the alphas results in quite a good result. The MSE is very low in comparison and also the R2 is good.

# %% [markdown]
# ## Elastic Nets Iteration 1
# Elastic Nets is a combination of Lasso and Ridge Regression.
#
# We will use CV for this only.

# %%
alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1]
l1_ratios = [ .1, .5, .7, .8, .9, .95, .99, 1]

# %%
ElasticNet1 = ElasticNetCV(cv=5, random_state=0, l1_ratio =l1_ratios, alphas=lambdas, fit_intercept=True )

# %%
ElasticNet1.fit(X, y)
# Out:
# ElasticNetCV(alphas=array([ 0.05,  1.1 ,  2.15,  3.2 ,  4.25,  5.3 ,  6.35,  7.4 ,  8.45,
#         9.5 , 10.55, 11.6 , 12.65, 13.7 , 14.75, 15.8 , 16.85, 17.9 ,
#        18.95, 20.  ]),
#        copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#        l1_ratio=[0.1, 0.5, 0.7, 0.8, 0.9, 0.95, 0.99, 1], max_iter=1000,
#        n_alphas=100, n_jobs=1, normalize=False, positive=False,
#        precompute='auto', random_state=0, selection='cyclic', tol=0.0001,
#        verbose=0)

# %%
ElasticNet1, ElasticNet1_summaries =  get_model_results(ElasticNet1,y, X, y, X,
                                                        y_pred_name="Sales_pred", 
                                                        y_name="Sales")

# %%
reg_model_results_plots(ElasticNet1_summaries, 
                        y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
print("L1 ratio: ", ElasticNet1.l1_ratio_)
print("Alpha: ", ElasticNet1.alpha_)
# Out:
# L1 ratio:  1.0
# Alpha:  0.05

# %% [markdown]
# The L1 ration is one, which means that this is basically  the Lasso regression, if we look closely we can see, that the results are the same as the last lasso Regression

# %%
el_net_coef = pd.Series(ElasticNet1.coef_, index = X_train.columns)

# %%
el_net_coef=el_net_coef.sort_values()

# %%
el_net_coef.plot(kind="barh")

# %%
print("Elastic Net picked " + str(sum(el_net_coef != 0)) + " variables and eliminated the other " +  str(sum(el_net_coef == 0)) + " variables")
# Out:
# Elastic Net picked 9 variables and eliminated the other 2 variables

# %% [markdown]
# ## Some other methods: KNN-Regression

# %%
n_neighbors = 10

# %%
knn = KNeighborsRegressor(n_neighbors=n_neighbors)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform')

# %%
knn, knn_summaries =  get_model_results(knn,y_train, X_train, y_test, X_test, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
reg_model_results_plots(knn_summaries,y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# As expected, the results are not very good. The model particularly does not handle values in the upper end very well. It is only a bit smaller than the Baseline Model.

# %% [markdown]
# ## PCA Analysis

# %%
X_values=X.values
y_values=y.values

# %%
# As we do not know how many components to choose, we select "None"
# as number of components to get an overview over the variance in the dataset
pca= PCA(n_components=None)
X_values_scaled= StandardScaler().fit_transform(X_values)
X_values_scaled= pca.fit_transform(X_values_scaled)

# %%
# We check our explained variance ratio in the dataset by adding each 
# consecutive principal component
np.cumsum(np.round(pca.explained_variance_ratio_,decimals=4)*100)
# Out:
# array([ 16.73,  31.82,  45.66,  55.66,  65.2 ,  74.08,  82.37,  90.02,
#         93.85,  97.5 , 100.01])

# %%
# For better understanding we plot the variance curve.
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# This curve quantifies how much of the total, 11-dimensional variance is contained within the first $N$ components. We see that the first ~7 components contain approximately 90% of the variance, while you need around 10 components to describe close to 100% of the variance.

# %% [markdown]
# ## PCR Analysis
# We build a function to perform a PCR. This concept combines a PCA and a logistic regression.
# Using Crossvalidation

# %%
def pcr(X,y,pc):
    pca3 = PCA()
     
    X_r= StandardScaler().fit_transform(X)
    X_r= pca.fit_transform(X)
    
    # Run PCA producing the reduced variable Xreg and select the first pc components
    Xreg = pca.fit_transform(X_r)[:,:pc]
 
    ''' Step 2: regression on selected principal components'''
 
    # Create linear regression object
    regr = LinearRegression()
    
    # Fit
    regr.fit(Xreg, y)
 
    # prediction of calibration
    y_c = regr.predict(Xreg)
 
    # Cross-validation
    y_cv = cross_val_predict(regr, Xreg, y, cv=10)
 
    # Calculate scores for calibration and cross-validation
    score_c = r2_score(y, y_c)
    score_cv = r2_score(y, y_cv)
 
    # Calculate mean square error for calibration and cross validation
    mse_c = mean_squared_error(y, y_c)
    mse_cv = mean_squared_error(y, y_cv)
 
    return(regr, y_cv, score_c, score_cv, mse_c, mse_cv, Xreg)

# %%
pcr, predicted, r2r, r2cv, mser, mscv, x_pcr=pcr(X_values,y_values, pc=7)

# %%
r2r
# Out:
# 0.5333562916027668

# %%
pcr, pcr_summaries = get_model_results(pcr,y,x_pcr, y, x_pcr,
                                       y_pred_name="Sales_pred", 
                                       y_name="Sales")

# %%
reg_model_results_plots(pcr_summaries, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# The model performs very bad compared to other models.

# %% [markdown]
# ## PLS
#
# Partial Least Squares:
#
# * Extension of a multiple linear regression model without restrictions
# * Technique similar to Principal Component Analysis (PCA).
# * Decomposes both the design matrix X and response vector/matrix Y (can have multiple responses at once) like in PCA and then performs regression between the obtained scores matrix and the eigenvectors.
# * The idea is to obtain decomposition of X and Y to be done by taking information from each other into account.

# %%
X_train_values=X_train.values
y_train_values=y_train.values
X_test_values=X_test.values
y_test_values=y_test.values

# %%
mse=[]
component = np.arange(1,11)

# %%
for i in component:
    pls1= PLSRegression(n_components=i)
    pls1.fit(X_train_values,y_train_values)
    y_pred = pls1.predict(X_test_values)
    
    mse_p = mean_squared_error(y_test_values,y_pred)
    mse.append(mse_p)

# %%
np.argmin(mse)
# Out:
# 3

# %%
msemin = np.argmin(mse)
print("Suggested number of components: ", msemin+1)
# Out:
# Suggested number of components:  4

# %%
with plt.style.context(('ggplot')):
     plt.plot(component, np.array(mse), '-v', color = 'blue', mfc='blue')
     plt.plot(component[msemin], np.array(mse)[msemin], 'P', ms=10, mfc='red')
     plt.xlabel('Number of PLS components')
     plt.ylabel('MSE')
     plt.title('PLS')
     plt.xlim(xmin=-1)
 
     plt.show()

# %%
pls = PLSRegression(n_components=msemin+1)
pls.fit(X_train_values, y_train_values)
Y_pred = pls.predict(X_test_values)

# %%
pls, pls_summaries = get_model_results(pls,y_train,X_train, y_test, X_test, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
reg_model_results_plots(pls_summaries, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# ## XGBoost

# %%
X_train = pd.DataFrame(data=X_train, columns=FEATURE_COLS)
X_test = pd.DataFrame(data=X_test, columns=FEATURE_COLS)

# %%
# DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed
data_dmatrix =xgb.DMatrix(data=X,label=y)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
         max_depth = 5, alpha = 10, n_estimators = 100)

# %%
xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)

# %%
xg_reg, xg_reg_summaries = get_model_results(xg_reg,y_train,X_train, y_test, X_test, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
reg_model_results_plots(xg_reg_summaries, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
xgb.plot_importance(xg_reg,max_num_features=15)
plt.show()

# %% [markdown]
# ### Cross-validation XGBoost

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.3,
          'max_depth': 5, 'alpha': 10, "n_estimators" : 100}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
# Out:
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14:21:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         5.594835        0.155352        5.622736       0.506954
# 1         4.334645        0.117921        4.391991       0.496998
# 2         3.480960        0.116280        3.577198       0.382047
# 3         2.940428        0.139525        3.087436       0.358730
# 4         2.574841        0.167244        2.773893       0.258306

# %%
print('Best number of trees = {}'.format(cv_results.shape[0]))
# Out:
# Best number of trees = 50

# %% [markdown]
# ### Hyperparameter

# %%
parameter_tuning= {
    'colsample_bytree':[0.4,0.6,0.8],
    'gamma':[0,0.03,0.1,0.3],
    'min_child_weight':[1.5,6,10],
    'learning_rate':[0.1,0.07],
}

# %%
xgb_model2 = xgb.XGBRegressor(learning_rate =0.1, n_estimators=100, max_depth=5,
              subsample=0.5, colsample_bytree=0.8, nthread=6, seed=27)

# %%
gsearch = GridSearchCV(estimator = xgb_model2, param_grid = parameter_tuning, n_jobs=6,iid=False,scoring='mean_squared_error')

# %%
model2 = gsearch1.fit(X_train, y_train)

# %%
gsearch1.fit(X_train,y_train)
print (gsearch1.grid_scores_)
print('best params')
print (gsearch1.best_params_)
print('best score')
print (gsearch1.best_score_)
# Out:
# [mean: -3.22377, std: 0.54623, params: {'colsample_bytree': 0.4, 'gamma': 0, 'learning_rate': 0.1, 'min_child_weight': 1.5}, mean: -2.72608, std: 0.37917, params: {'colsample_bytree': 0.4, 'gamma': 0, 'learning_rate': 0.1, 'min_child_weight': 6}, mean: -2.50322, std: 0.53095, params: {'colsample_bytree': 0.4, 'gamma': 0, 'learning_rate': 0.1, 'min_child_weight': 10}, mean: -3.35188, std: 0.46851, params: {'colsample_bytree': 0.4, 'gamma': 0, 'learning_rate': 0.07, 'min_child_weight': 1.5}, mean: -2.94640, std: 0.40547, params: {'colsample_bytree': 0.4, 'gamma': 0, 'learning_rate': 0.07, 'min_child_weight': 6}, mean: -2.82649, std: 0.67055, params: {'colsample_bytree': 0.4, 'gamma': 0, 'learning_rate': 0.07, 'min_child_weight': 10}, mean: -3.24822, std: 0.55289, params: {'colsample_bytree': 0.4, 'gamma': 0.03, 'learning_rate': 0.1, 'min_child_weight': 1.5}, mean: -2.71581, std: 0.34397, params: {'colsample_bytree': 0.4, 'gamma': 0.03, 'learning_rate': 0.1, 'min_child_weight': 6}, mean: -2.50044, std: 0.52772, params: {'colsample_bytree': 0.4, 'gamma': 0.03, 'learning_rate': 0.1, 'min_child_weight': 10}, mean: -3.36412, std: 0.48065, params: {'colsample_bytree': 0.4, 'gamma': 0.03, 'learning_rate': 0.07, 'min_child_weight': 1.5}, mean: -2.95053, std: 0.40786, params: {'colsample_bytree': 0.4, 'gamma': 0.03, 'learning_rate': 0.07, 'min_child_weight': 6}, mean: -2.82910, std: 0.64238, params: {'colsample_bytree': 0.4, 'gamma': 0.03, 'learning_rate': 0.07, 'min_child_weight': 10}, mean: -3.17444, std: 0.53619, params: {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.1, 'min_child_weight': 1.5}, mean: -2.72490, std: 0.37554, params: {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.1, 'min_child_weight': 6}, mean: -2.49279, std: 0.49288, params: {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.1, 'min_child_weight': 10}, mean: -3.36836, std: 0.43514, params: {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.07, 'min_child_weight': 1.5}, mean: -2.88963, std: 0.38250, params: {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.07, 'min_child_weight': 6}, mean: -2.80610, std: 0.66061, params: {'colsample_bytree': 0.4, 'gamma': 0.1, 'learning_rate': 0.07, 'min_child_weight': 10}, mean: -3.27953, std: 0.54185, params: {'colsample_bytree': 0.4, 'gamma': 0.3, 'learning_rate': 0.1, 'min_child_weight': 1.5}, mean: -2.64078, std: 0.44018, params: {'colsample_bytree': 0.4, 'gamma': 0.3, 'learning_rate': 0.1, 'min_child_weight': 6}, mean: -2.51761, std: 0.50007, params: {'colsample_bytree': 0.4, 'gamma': 0.3, 'learning_rate': 0.1, 'min_child_weight': 10}, mean: -3.42445, std: 0.39064, params: {'colsample_bytree': 0.4, 'gamma': 0.3, 'learning_rate': 0.07, 'min_child_weight': 1.5}, mean: -2.87840, std: 0.41244, params: {'colsample_bytree': 0.4, 'gamma': 0.3, 'learning_rate': 0.07, 'min_child_weight': 6}, mean: -2.86024, std: 0.72200, params: {'colsample_bytree': 0.4, 'gamma': 0.3, 'learning_rate': 0.07, 'min_child_weight': 10}, mean: -2.54192, std: 0.35977, params: {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.1, 'min_child_weight': 1.5}, mean: -2.25341, std: 0.19679, params: {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.1, 'min_child_weight': 6}, mean: -2.17748, std: 0.44746, params: {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.1, 'min_child_weight': 10}, mean: -2.66764, std: 0.38961, params: {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.07, 'min_child_weight': 1.5}, mean: -2.35761, std: 0.38283, params: {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.07, 'min_child_weight': 6}, mean: -2.32021, std: 0.54805, params: {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.07, 'min_child_weight': 10}, mean: -2.58248, std: 0.37146, params: {'colsample_bytree': 0.6, 'gamma': 0.03, 'learning_rate': 0.1, 'min_child_weight': 1.5}, mean: -2.22783, std: 0.18334, params: {'colsample_bytree': 0.6, 'gamma': 0.03, 'learning_rate': 0.1, 'min_child_weight': 6},  ...
# best params
# {'colsample_bytree': 0.8, 'gamma': 0.03, 'learning_rate': 0.1, 'min_child_weight': 6}
# best score
# -1.9982820757562711

# %%
xgb_model2 = xgb.XGBRegressor(learning_rate =0.1, n_estimators=100, max_depth=5,gamma=0.03,
              subsample=0.5, colsample_bytree=0.8,nthread=6, min_child_weight=6, seed=27)

# %%
xgb_model2.fit(X_train,y_train)

preds = xgb_model2.predict(X_test)

# %%
xgb_model2, xgb_model2_summaries = get_model_results(xgb_model2,y_train,X_train, y_test, X_test, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %%
reg_model_results_plots(xgb_model2_summaries, y_pred_name="Sales_pred", 
                        y_name="Sales")

# %% [markdown]
# ## Summary
# The results overall were quite well except of PCR and KNN.
# All the models we built using CV were the best (but they also had more samples.)
# The best RMSLE we scored with Lasso after a few iterations and the PLS.
# Although the R² was not as good for PLS as for the Lasso model.
#
# Lasso and ElasticNets helped us figuring out the important features, which could be used in further Feature Engineering or modelling.
